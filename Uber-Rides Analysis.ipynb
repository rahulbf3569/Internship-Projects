# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('uber-rides-dataset.csv')

# %% [markdown]
# #Exploring Data

# %%
data.shape
# Out:
# (678, 48)

# %%
data.head(3)
# Out:
#          trip_completed_at trip_status ride_hailing_app  \
# 0   May 11, 2015 at 6:55PM   Completed             Uber
# 1   May 11, 2015 at 8:12PM   Completed             Uber
# 2  May 13, 2015 at 11:38AM   Completed             Uber
#
#                            trip_uid                        driver_uid  \
# 0  ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1  518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# 2  6e460cc8a12c3c6568d0d4a67ac58393  cb249a2bd807ca78697b4ed0348c37da
#
#                           rider_uid  customer trip_start_date trip_start_time  \
# 0  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      11-05-2015        17:26:00
# 1  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      11-05-2015        18:46:00
# 2  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      13-05-2015        09:15:00
#
#   trip_end_date  ... temperature_date temperature_time temperature_value  \
# ...

# %%
data.tail(3)
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 675  1879ce44367d4cc555479253323ec36d  b65196da38435a1dbe8e9009b514a7b8
# 676  7a237cb245b6ca854498ecb7c842beb3  2af94300321de81edc1eeef8c041fd9a
# 677  f794daa1e63029828ec58248549815d2  ab02b9b447412505a2f42cefab54520b
#
#                             rider_uid  customer trip_start_date  \
# 675  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      26-04-2018
# 676  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      26-04-2018
# 677  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan      27-04-2018
#
#     trip_start_time trip_end_date  ... temperature_date temperature_time  \
# 675        15:22:00    26-04-2018  ...       26-04-2018         15:22:00
# ...

# %%
data.sample(10)
# Out:
#                  trip_completed_at trip_status ride_hailing_app  \
# 615   February 19, 2018 at 11:56AM   Completed             Uber
# 356        June 15, 2017 at 5:57PM   Completed             Uber
# 197        July 23, 2016 at 5:29PM   Completed             Uber
# 580    January 30, 2018 at 09:23AM   Completed             Uber
# 17          June 6, 2015 at 2:59PM   Completed             Uber
# 515   December 20, 2017 at 03:21PM   Completed             Uber
# 440   November 23, 2017 at 12:46PM   Completed             Uber
# 394      August 12, 2017 at 1:48PM   Completed             Uber
# 92   September 28, 2015 at 10:05AM   Completed             Uber
# 95   September 29, 2015 at 11:19AM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 615  e07f359d9b39dda01277b8fb19d08f12  164cdace271ca4165ded891d0c2fdd14
# 356  2e97407ebaafa354af15efde43e9082b  329917d917aee0375f98d8eea90c6f6e
# ...

# %%
data.describe()
# Out:
#        surge_multiplier  pickup_lat  pickup_long  dropoff_lat  dropoff_long  \
# count        643.000000  678.000000   678.000000   678.000000    678.000000
# mean           1.011353   59.756784    31.740062    59.758561     31.739366
# std            0.096085    0.800432     6.063872     0.799396      6.062101
# min            1.000000   55.605800    30.168447    55.599648     29.947507
# 25%            1.000000   59.932134    30.364931    59.933576     30.366456
# 50%            1.000000   59.941415    30.366456    59.941415     30.368724
# 75%            1.000000   59.960492    30.420179    59.961987     30.417860
# max            2.900000   60.126500    60.809913    60.126957     60.809916
#
#        rub_usd_exchange_rate    price_rub   price_usd  distance_kms  \
# count             678.000000   678.000000  678.000000    678.000000
# mean               60.517463   303.360280    5.061593     10.057788
# std                 4.526606   249.965109    4.251843      8.735132
# ...

# %%
data.describe(include='all')
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# count                      678         678              678
# unique                     678           2                2
# top     May 11, 2015 at 6:55PM   Completed             Uber
# freq                         1         668              642
# mean                       NaN         NaN              NaN
# std                        NaN         NaN              NaN
# min                        NaN         NaN              NaN
# 25%                        NaN         NaN              NaN
# 50%                        NaN         NaN              NaN
# 75%                        NaN         NaN              NaN
# max                        NaN         NaN              NaN
#
#                                 trip_uid                        driver_uid  \
# count                                678                               678
# unique                               678                               628
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678 entries, 0 to 677
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_completed_at      678 non-null    object
#  1   trip_status            678 non-null    object
#  2   ride_hailing_app       678 non-null    object
#  3   trip_uid               678 non-null    object
#  4   driver_uid             678 non-null    object
#  5   rider_uid              678 non-null    object
#  6   customer               678 non-null    object
#  7   trip_start_date        678 non-null    object
#  8   trip_start_time        678 non-null    object
#  9   trip_end_date          678 non-null    object
#  10  trip_end_time          678 non-null    object
#  11  trip_time              678 non-null    object
#  12  total_time             678 non-null    object
#  13  wait_time              678 non-null    object
# ...

# %% [markdown]
# ## (3)Drop Duplicates

# %%
data_dup = data.duplicated().sum()

# %%
data_dup
# Out:
# 0

# %% [markdown]
# # (4) Missing Values

# %%
data.isnull()
# Out:
#      trip_completed_at  trip_status  ride_hailing_app  trip_uid  driver_uid  \
# 0                False        False             False     False       False
# 1                False        False             False     False       False
# 2                False        False             False     False       False
# 3                False        False             False     False       False
# 4                False        False             False     False       False
# ..                 ...          ...               ...       ...         ...
# 673              False        False             False     False       False
# 674              False        False             False     False       False
# 675              False        False             False     False       False
# 676              False        False             False     False       False
# 677              False        False             False     False       False
#
# ...

# %%
data.isna()
# Out:
#      trip_completed_at  trip_status  ride_hailing_app  trip_uid  driver_uid  \
# 0                False        False             False     False       False
# 1                False        False             False     False       False
# 2                False        False             False     False       False
# 3                False        False             False     False       False
# 4                False        False             False     False       False
# ..                 ...          ...               ...       ...         ...
# 673              False        False             False     False       False
# 674              False        False             False     False       False
# 675              False        False             False     False       False
# 676              False        False             False     False       False
# 677              False        False             False     False       False
#
# ...

# %%
data.isna().sum()
# Out:
# trip_completed_at         0
# trip_status               0
# ride_hailing_app          0
# trip_uid                  0
# driver_uid                0
# rider_uid                 0
# customer                  0
# trip_start_date           0
# trip_start_time           0
# trip_end_date             0
# trip_end_time             0
# trip_time                 0
# total_time                0
# wait_time                 0
# trip_type                 0
# surge_multiplier         35
# vehicle_make_model        0
# vehicle_license_plate     0
# driver_name_en            0
# vehicle_make              0
# vehicle_model             0
# driver_gender             0
# driver_photo_url          0
# driver_phone_number       0
# pickup_lat                0
# pickup_long               0
# dropoff_lat               0
# dropoff_long              0
# trip_map_image_url        0
# trip_path_image_url       0
# city                      0
# country                   0
# trip_start_address        0
# ...

# %%
data = data.fillna(0)

# %%
data.isna().sum()
# Out:
# trip_completed_at        0
# trip_status              0
# ride_hailing_app         0
# trip_uid                 0
# driver_uid               0
# rider_uid                0
# customer                 0
# trip_start_date          0
# trip_start_time          0
# trip_end_date            0
# trip_end_time            0
# trip_time                0
# total_time               0
# wait_time                0
# trip_type                0
# surge_multiplier         0
# vehicle_make_model       0
# vehicle_license_plate    0
# driver_name_en           0
# vehicle_make             0
# vehicle_model            0
# driver_gender            0
# driver_photo_url         0
# driver_phone_number      0
# pickup_lat               0
# pickup_long              0
# dropoff_lat              0
# dropoff_long             0
# trip_map_image_url       0
# trip_path_image_url      0
# city                     0
# country                  0
# trip_start_address       0
# trip_end_address         0
# ...

# %% [markdown]
# ## (5)Drop Unneccessary Columns

# %%
data.columns
# Out:
# Index(['trip_completed_at', 'trip_status', 'ride_hailing_app', 'trip_uid',
#        'driver_uid', 'rider_uid', 'customer', 'trip_start_date',
#        'trip_start_time', 'trip_end_date', 'trip_end_time', 'trip_time',
#        'total_time', 'wait_time', 'trip_type', 'surge_multiplier',
#        'vehicle_make_model', 'vehicle_license_plate', 'driver_name_en',
#        'vehicle_make', 'vehicle_model', 'driver_gender', 'driver_photo_url',
#        'driver_phone_number', 'pickup_lat', 'pickup_long', 'dropoff_lat',
#        'dropoff_long', 'trip_map_image_url', 'trip_path_image_url', 'city',
#        'country', 'trip_start_address', 'trip_end_address',
#        'rub_usd_exchange_rate', 'price_rub', 'price_usd', 'distance_kms',
#        'temperature_date', 'temperature_time', 'temperature_value',
#        'feels_like', 'humidity', 'wind_speed', 'cloudness', 'weather_main',
#        'weather_desc', 'precipitation'],
#       dtype='object')

# %%
cols = ['trip_completed_at','trip_uid', 'driver_uid', 'rider_uid', 'customer', 'vehicle_make_model', 'vehicle_license_plate','driver_name_en', 'vehicle_make', 'vehicle_model','driver_photo_url', 'driver_phone_number', 'pickup_lat', 'pickup_long', 'dropoff_lat', 'dropoff_long', 'trip_map_image_url','trip_path_image_url', 'country', 'trip_start_address','trip_end_address']

# %%
for i in cols:
    data1 = data.drop(i, inplace = True, axis = 1)

# %%
data.shape
# Out:
# (678, 27)

# %%
data.columns
# Out:
# Index(['trip_status', 'ride_hailing_app', 'trip_start_date', 'trip_start_time',
#        'trip_end_date', 'trip_end_time', 'trip_time', 'total_time',
#        'wait_time', 'trip_type', 'surge_multiplier', 'driver_gender', 'city',
#        'rub_usd_exchange_rate', 'price_rub', 'price_usd', 'distance_kms',
#        'temperature_date', 'temperature_time', 'temperature_value',
#        'feels_like', 'humidity', 'wind_speed', 'cloudness', 'weather_main',
#        'weather_desc', 'precipitation'],
#       dtype='object')

# %%
data.head(3)
# Out:
#   trip_status ride_hailing_app trip_start_date trip_start_time trip_end_date  \
# 0   Completed             Uber      11-05-2015        17:26:00    11-05-2015
# 1   Completed             Uber      11-05-2015        18:46:00    11-05-2015
# 2   Completed             Uber      13-05-2015        09:15:00    13-05-2015
#
#   trip_end_time trip_time total_time wait_time trip_type  ...  \
# 0      17:55:00  00:21:33   00:29:00  00:07:27     uberX  ...
# 1      19:12:00  00:19:27   00:26:00  00:06:33     uberX  ...
# 2      10:38:00  01:06:53   01:23:00  00:16:07     uberX  ...
#
#    temperature_date temperature_time temperature_value  feels_like  humidity  \
# 0        11-05-2015         17:26:00                12          12      0.69
# 1        11-05-2015         18:46:00                10          10      0.70
# 2        13-05-2015         09:15:00                14          14      0.61
#
#    wind_speed  cloudness       weather_main   weather_desc  precipitation
# ...

# %%
data.tail(3)
# Out:
#     trip_status ride_hailing_app trip_start_date trip_start_time  \
# 675   Completed             Uber      26-04-2018        15:22:00
# 676   Completed             Uber      26-04-2018        16:37:00
# 677   Completed             Uber      27-04-2018        14:15:00
#
#     trip_end_date trip_end_time trip_time total_time wait_time trip_type  ...  \
# 675    26-04-2018      15:57:00  00:16:20   00:35:00  00:18:40     uberX  ...
# 676    26-04-2018      17:00:00  00:19:19   00:23:00  00:03:41     uberX  ...
# 677    27-04-2018      15:05:00  00:32:46   00:50:00  00:17:14     uberX  ...
#
#      temperature_date temperature_time temperature_value  feels_like  \
# 675        26-04-2018         15:22:00                 8           6
# 676        26-04-2018         16:37:00                 9           7
# 677        27-04-2018         14:15:00                 8           7
#
#      humidity  wind_speed  cloudness       weather_main   weather_desc  \
# ...

# %% [markdown]
# ## (6) categorizing the data

# %%
data.columns
# Out:
# Index(['trip_status', 'ride_hailing_app', 'trip_start_date', 'trip_start_time',
#        'trip_end_date', 'trip_end_time', 'trip_time', 'total_time',
#        'wait_time', 'trip_type', 'surge_multiplier', 'driver_gender', 'city',
#        'rub_usd_exchange_rate', 'price_rub', 'price_usd', 'distance_kms',
#        'temperature_date', 'temperature_time', 'temperature_value',
#        'feels_like', 'humidity', 'wind_speed', 'cloudness', 'weather_main',
#        'weather_desc', 'precipitation'],
#       dtype='object')

# %%
cat_cols = ['trip_status', 'ride_hailing_app', 'trip_type',
       'driver_gender', 'city','weather_main', 'weather_desc', 'precipitation']

# %%
for i in cat_cols:
    data[i] = data[i].astype('category')

# %%
data.dtypes
# Out:
# trip_status              category
# ride_hailing_app         category
# trip_start_date            object
# trip_start_time            object
# trip_end_date              object
# trip_end_time              object
# trip_time                  object
# total_time                 object
# wait_time                  object
# trip_type                category
# surge_multiplier          float64
# driver_gender            category
# city                     category
# rub_usd_exchange_rate     float64
# price_rub                 float64
# price_usd                 float64
# distance_kms              float64
# temperature_date           object
# temperature_time           object
# temperature_value           int64
# feels_like                  int64
# humidity                  float64
# wind_speed                float64
# cloudness                 float64
# weather_main             category
# weather_desc             category
# precipitation            category
# dtype: object

# %%
data.shape
# Out:
# (678, 27)

# %%
num_cols = ['price_rub','cloudness']

# %%
for i in num_cols:
    data[i] = data[i].astype('float')

# %%
data.dtypes
# Out:
# trip_status              category
# ride_hailing_app         category
# trip_start_date            object
# trip_start_time            object
# trip_end_date              object
# trip_end_time              object
# trip_time                  object
# total_time                 object
# wait_time                  object
# trip_type                category
# surge_multiplier          float64
# driver_gender            category
# city                     category
# rub_usd_exchange_rate     float64
# price_rub                 float64
# price_usd                 float64
# distance_kms              float64
# temperature_date           object
# temperature_time           object
# temperature_value           int64
# feels_like                  int64
# humidity                  float64
# wind_speed                float64
# cloudness                 float64
# weather_main             category
# weather_desc             category
# precipitation            category
# dtype: object

# %%
data.columns
# Out:
# Index(['trip_status', 'ride_hailing_app', 'trip_start_date', 'trip_start_time',
#        'trip_end_date', 'trip_end_time', 'trip_time', 'total_time',
#        'wait_time', 'trip_type', 'surge_multiplier', 'driver_gender', 'city',
#        'rub_usd_exchange_rate', 'price_rub', 'price_usd', 'distance_kms',
#        'temperature_date', 'temperature_time', 'temperature_value',
#        'feels_like', 'humidity', 'wind_speed', 'cloudness', 'weather_main',
#        'weather_desc', 'precipitation'],
#       dtype='object')

# %%
from datetime import datetime

# %%
data.trip_start_date=pd.to_datetime(data.trip_start_date)
data.trip_end_date=pd.to_datetime(data.trip_end_date)
data.trip_start_time=pd.to_datetime(data.trip_start_time)
data.trip_time=pd.to_datetime(data.trip_time)
data.total_time=pd.to_datetime(data.total_time)
data.wait_time=pd.to_datetime(data.wait_time)
data.temperature_date=pd.to_datetime(data.temperature_date)
data.temperature_time=pd.to_datetime(data.temperature_time)
data.trip_end_time=pd.to_datetime(data.trip_end_time)

# %%
data.dtypes
# Out:
# trip_status                    category
# ride_hailing_app               category
# trip_start_date          datetime64[ns]
# trip_start_time          datetime64[ns]
# trip_end_date            datetime64[ns]
# trip_end_time            datetime64[ns]
# trip_time                datetime64[ns]
# total_time               datetime64[ns]
# wait_time                datetime64[ns]
# trip_type                      category
# surge_multiplier                float64
# driver_gender                  category
# city                           category
# rub_usd_exchange_rate           float64
# price_rub                       float64
# price_usd                       float64
# distance_kms                    float64
# temperature_date         datetime64[ns]
# temperature_time         datetime64[ns]
# temperature_value                 int64
# feels_like                        int64
# humidity                        float64
# wind_speed                      float64
# ...

# %% [markdown]
# <h1>Segregating The Data

# %%
data.corr()
# Out:
#                        surge_multiplier  rub_usd_exchange_rate  price_rub  \
# surge_multiplier               1.000000              -0.111381   0.037041
# rub_usd_exchange_rate         -0.111381               1.000000  -0.064987
# price_rub                      0.037041              -0.064987   1.000000
# price_usd                      0.058944              -0.153752   0.992329
# distance_kms                   0.001845              -0.053971   0.741098
# temperature_value             -0.065284               0.140562   0.066632
# feels_like                    -0.066376               0.154584   0.072875
# humidity                      -0.030640              -0.078768  -0.008969
# wind_speed                     0.046386              -0.067809  -0.018052
# cloudness                     -0.087093              -0.069223  -0.068245
#
#                        price_usd  distance_kms  temperature_value  feels_like  \
# ...

# %%
data_1=data.drop(['trip_status','ride_hailing_app','trip_start_date','trip_start_time','trip_end_date','trip_time','trip_end_time','total_time','wait_time','trip_type','driver_gender','city','temperature_date','temperature_time','weather_main','weather_desc','precipitation'],axis=1)

# %%
data_2=data_1.drop(['temperature_value','feels_like','humidity','wind_speed','cloudness'],axis=1)

# %%
data_2
# Out:
#      surge_multiplier  rub_usd_exchange_rate  price_rub  price_usd  \
# 0                 1.0                  51.28      265.0       5.17
# 1                 1.0                  51.28      255.0       4.97
# 2                 1.0                  49.50      644.0      13.01
# 3                 2.9                  49.53     1287.0      25.99
# 4                 1.4                  49.53      665.0      13.43
# ..                ...                    ...        ...        ...
# 673               1.0                  61.82      161.0       2.60
# 674               1.0                  61.54      241.0       3.92
# 675               1.0                  62.68      174.0       2.78
# 676               1.0                  62.68      209.0       3.33
# 677               1.0                  62.13      212.0       3.41
#
#      distance_kms
# 0            9.29
# 1            9.93
# 2           18.01
# 3            5.10
# 4           21.92
# ..            ...
# 673          5.79
# ...

# %%
data_3=data_1.drop(['surge_multiplier','rub_usd_exchange_rate','price_rub','price_usd','distance_kms'],axis=1)
data_3
# Out:
#      temperature_value  feels_like  humidity  wind_speed  cloudness
# 0                   12          12      0.69        4.81       0.78
# 1                   10          10      0.70        6.53       0.66
# 2                   14          14      0.61        5.25       0.86
# 3                    3           3      0.84        0.87       0.56
# 4                    3           1      0.90        1.61       0.31
# ..                 ...         ...       ...         ...        ...
# 673                  6           4      0.39        2.57       0.18
# 674                  7           3      0.62        5.37       0.48
# 675                  8           6      0.76        4.02       0.90
# 676                  9           7      0.68        4.28       0.79
# 677                  8           7      0.77        1.56       0.75
#
# [678 rows x 5 columns]

# %%
data_price=data_1.drop(['surge_multiplier','rub_usd_exchange_rate','price_rub','distance_kms','temperature_value','feels_like','humidity','wind_speed','cloudness'],axis=1)
data_price
# Out:
#      price_usd
# 0         5.17
# 1         4.97
# 2        13.01
# 3        25.99
# 4        13.43
# ..         ...
# 673       2.60
# 674       3.92
# 675       2.78
# 676       3.33
# 677       3.41
#
# [678 rows x 1 columns]

# %% [markdown]
# <h1>PCA

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier

# %%
pca=PCA(n_components=5)
fit=pca.fit(data_2)
print(fit.components_)
# Out:
# [[ 3.59334765e-05 -1.17722820e-03  9.99521476e-01  1.68711371e-02
#    2.58997255e-02]
#  [ 1.53610329e-03  1.50743502e-02  2.57432637e-02  1.02863588e-02
#   -9.99500815e-01]
#  [-5.95387130e-03  9.96288324e-01  2.23460731e-03 -8.46605460e-02
#    1.42030206e-02]
#  [-1.68915199e-01 -8.43176021e-02  1.67692609e-02 -9.81810301e-01
#   -1.12036545e-02]
#  [ 9.85611407e-01 -8.45552868e-03  2.81087149e-03 -1.68791824e-01
#   -2.77491456e-04]]

# %%
x = data_2.loc[:,['surge_multiplier','rub_usd_exchange_rate','price_rub','distance_kms']].values
x
# Out:
# array([[  1.  ,  51.28, 265.  ,   9.29],
#        [  1.  ,  51.28, 255.  ,   9.93],
#        [  1.  ,  49.5 , 644.  ,  18.01],
#        ...,
#        [  1.  ,  62.68, 174.  ,   6.68],
#        [  1.  ,  62.68, 209.  ,   7.48],
#        [  1.  ,  62.13, 212.  ,   9.03]])

# %%
pca = PCA(n_components=5)
pca.fit(data_2)

# Reformat and view results
loadings = pd.DataFrame(pca.components_.T,
columns=['PC%s' % _ for _ in range(len(data_2.columns))],
index=data_2.columns)
print(loadings)


plt.plot(pca.explained_variance_ratio_)
plt.ylabel('Explained Variance')
plt.xlabel('Components')
plt.show()

pca = PCA(n_components=2)
pc = pca.fit_transform(x)
ppca = pd.DataFrame(data = pc
             , columns = [ 'pc1', 'pc2'])
# Out:
#                             PC0       PC1       PC2       PC3       PC4
# surge_multiplier       0.000036  0.001536 -0.005954 -0.168915  0.985611
# rub_usd_exchange_rate -0.001177  0.015074  0.996288 -0.084318 -0.008456
# price_rub              0.999521  0.025743  0.002235  0.016769  0.002811
# price_usd              0.016871  0.010286 -0.084661 -0.981810 -0.168792
# distance_kms           0.025900 -0.999501  0.014203 -0.011204 -0.000277

# %%
loadings.sample(5)
# Out:
#                             PC0       PC1       PC2       PC3       PC4
# surge_multiplier       0.000036  0.001536 -0.005954 -0.168915  0.985611
# price_rub              0.999521  0.025743  0.002235  0.016769  0.002811
# rub_usd_exchange_rate -0.001177  0.015074  0.996288 -0.084318 -0.008456
# distance_kms           0.025900 -0.999501  0.014203 -0.011204 -0.000277
# price_usd              0.016871  0.010286 -0.084661 -0.981810 -0.168792

# %%
ppca.sample(10)
# Out:
#             pc1        pc2
# 172  -62.393498   0.350453
# 154  -71.396511   0.297018
# 279 -119.179636   3.315218
# 673 -142.424494   0.597262
# 493 -145.444198   1.402162
# 666  304.163683 -16.257484
# 10   -89.431901   1.909542
# 261  -65.851087   0.243449
# 365  376.148716 -14.717988
# 210  127.654930   0.957818

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('pc1')
ax.set_ylabel('pc2')
ax.scatter(ppca['pc1'], ppca['pc2'])

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(data_1.corr(), annot=True,cmap="mako")
plt.show()

# %% [markdown]
# <h1>KMeans

# %%
from sklearn.cluster import KMeans

# %%
x
# Out:
# array([[  1.  ,  51.28, 265.  ,   9.29],
#        [  1.  ,  51.28, 255.  ,   9.93],
#        [  1.  ,  49.5 , 644.  ,  18.01],
#        ...,
#        [  1.  ,  62.68, 174.  ,   6.68],
#        [  1.  ,  62.68, 209.  ,   7.48],
#        [  1.  ,  62.13, 212.  ,   9.03]])

# %%
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init='k-means++')
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,11),wcss,linewidth=2,color='red',marker='8')
plt.title("Elbow Graph")
plt.xlabel("K value")
plt.ylabel('WCSS')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0, 0.5, 'WCSS')

# %%
kmeans=KMeans(n_clusters=4)
kmeans.fit(x)
pr=kmeans.predict(x)
print(kmeans.labels_[:100])
# Out:
# [0 0 1 2 1 0 3 3 0 3 0 3 3 0 0 0 0 0 3 0 3 0 1 1 1 1 3 1 3 2 3 1 0 3 0 3 0
#  0 3 3 0 1 3 3 0 2 2 1 1 3 0 0 0 3 3 0 0 0 0 0 0 0 0 3 3 1 0 0 0 3 3 0 3 0
#  0 3 0 0 3 3 0 0 1 0 3 0 0 0 0 3 0 0 0 0 0 3 3 0 0 0]

# %%
kmeans.cluster_centers_[:100]
label=kmeans.labels_
label
plt.scatter(ppca['pc1'], ppca['pc2'], c=pr, cmap='plasma')

# %%
plt.scatter(ppca['pc1'], ppca['pc2'], c=pr, cmap='plasma')

# %%
data_2['cluster']=label
data_2
# Out:
#      surge_multiplier  rub_usd_exchange_rate  price_rub  price_usd  \
# 0                 1.0                  51.28      265.0       5.17
# 1                 1.0                  51.28      255.0       4.97
# 2                 1.0                  49.50      644.0      13.01
# 3                 2.9                  49.53     1287.0      25.99
# 4                 1.4                  49.53      665.0      13.43
# ..                ...                    ...        ...        ...
# 673               1.0                  61.82      161.0       2.60
# 674               1.0                  61.54      241.0       3.92
# 675               1.0                  62.68      174.0       2.78
# 676               1.0                  62.68      209.0       3.33
# 677               1.0                  62.13      212.0       3.41
#
#      distance_kms  cluster
# 0            9.29        0
# 1            9.93        0
# 2           18.01        1
# 3            5.10        2
# ...

# %%
sns.set_theme(style="whitegrid")
sns.violinplot(x=data_2['price_usd'],y=data_2['cluster'])
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='cluster'>

# %% [markdown]
# <h1>Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
x_pca= pca.fit_transform(data_2)

# %%
x_pca
# Out:
# array([[-3.83509548e+01, -3.42799904e-01],
#        [-4.83329455e+01, -1.24218173e+00],
#        [ 3.40829164e+02,  7.49747206e-01],
#        ...,
#        [-1.29428545e+02,  6.34178611e-02],
#        [-9.44153730e+01,  1.71515435e-01],
#        [-9.13746737e+01, -1.30750769e+00]])

# %%
lm = LinearRegression()
lm.fit(x_pca, data_price)
# Out:
# LinearRegression()

# %%
y_predict = lm.predict(x_pca)
r2_score(data_price, y_predict)
# Out:
# 0.9849129487641657

# %%
y_mse = mean_squared_error(data_price, y_predict)
y_mse
# Out:
# 0.27234402286786746

# %%
plt.scatter(data_price, y_predict)
plt.title('residual plot')
plt.xlabel('y')
plt.ylabel('y_predict')
plt.show()

# %% [markdown]
# <h1>binomial distributions

# %%
data_m=data_2.groupby(data_2['cluster'])
data_m.mean()
data_m.plot(cmap='mako')
# Out:
# cluster
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# <h1>profiling segments

# %%
data_2.hist()
# Out:
# array([[<AxesSubplot:title={'center':'surge_multiplier'}>,
#         <AxesSubplot:title={'center':'rub_usd_exchange_rate'}>],
#        [<AxesSubplot:title={'center':'price_rub'}>,
#         <AxesSubplot:title={'center':'price_usd'}>],
#        [<AxesSubplot:title={'center':'distance_kms'}>,
#         <AxesSubplot:title={'center':'cluster'}>]], dtype=object)

# %%
data_m.hist()
# Out:
# cluster
# 0    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 2    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# 3    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# dtype: object

# %% [markdown]
# <h1>Describing Segments

# %%
from statsmodels.graphics.mosaicplot import mosaic
from itertools import product

# %%
list=['surge_multiplier','rub_usd_exchange_rate','price_rub','price_usd','distance_kms','cluster']

# %%
data_2
# Out:
#      surge_multiplier  rub_usd_exchange_rate  price_rub  price_usd  \
# 0                 1.0                  51.28      265.0       5.17
# 1                 1.0                  51.28      255.0       4.97
# 2                 1.0                  49.50      644.0      13.01
# 3                 2.9                  49.53     1287.0      25.99
# 4                 1.4                  49.53      665.0      13.43
# ..                ...                    ...        ...        ...
# 673               1.0                  61.82      161.0       2.60
# 674               1.0                  61.54      241.0       3.92
# 675               1.0                  62.68      174.0       2.78
# 676               1.0                  62.68      209.0       3.33
# 677               1.0                  62.13      212.0       3.41
#
#      distance_kms  cluster
# 0            9.29        0
# 1            9.93        0
# 2           18.01        1
# 3            5.10        2
# ...

# %%
sns.heatmap(x)
plt.show()

# %%
sns.heatmap(data_2)
plt.show()

# %% [markdown]
# <h1>Customising Market Mix

# %%
plt.scatter(data_2['distance_kms'],data_price)

# %%
sns.boxplot(data=data_2,palette='mako')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=data_2,palette='rocket')
# Out:
# <AxesSubplot:>
